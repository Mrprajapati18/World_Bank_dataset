# %% [markdown]
# # Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Import dataset

# %%
 Health= pd.read_csv(r"C:\Users\durge\OneDrive\Desktop\python_project\Health_systems.csv")

# %%
Health
# Out:
#     Country_Region  Province_State        World_Bank_Name  \
# 0      Afghanistan             NaN            Afghanistan
# 1          Albania             NaN                Albania
# 2          Algeria             NaN                Algeria
# 3          Andorra             NaN                Andorra
# 4           Angola             NaN                 Angola
# ..             ...             ...                    ...
# 205             US  Virgin Islands  Virgin Islands (U.S.)
# 206            NaN             NaN     West Bank and Gaza
# 207            NaN             NaN            Yemen, Rep.
# 208         Zambia             NaN                 Zambia
# 209       Zimbabwe             NaN               Zimbabwe
#
#      Health_exp_pct_GDP_2016  Health_exp_public_pct_2016  \
# 0                       10.2                         5.1
# 1                        6.7                        41.4
# 2                        6.6                        67.7
# ...

# %%
Health.head(10)
# Out:
#         Country_Region Province_State      World_Bank_Name  \
# 0          Afghanistan            NaN          Afghanistan
# 1              Albania            NaN              Albania
# 2              Algeria            NaN              Algeria
# 3              Andorra            NaN              Andorra
# 4               Angola            NaN               Angola
# 5  Antigua and Barbuda            NaN  Antigua and Barbuda
# 6            Argentina            NaN            Argentina
# 7              Armenia            NaN              Armenia
# 8            Australia            NaN            Australia
# 9              Austria            NaN              Austria
#
#    Health_exp_pct_GDP_2016  Health_exp_public_pct_2016  \
# 0                     10.2                         5.1
# 1                      6.7                        41.4
# 2                      6.6                        67.7
# 3                     10.4                        49.1
# ...

# %%
Health.tail(10)
# Out:
#     Country_Region  Province_State        World_Bank_Name  \
# 200        Uruguay             NaN                Uruguay
# 201     Uzbekistan             NaN             Uzbekistan
# 202            NaN             NaN                Vanuatu
# 203      Venezuela             NaN          Venezuela, RB
# 204        Vietnam             NaN                Vietnam
# 205             US  Virgin Islands  Virgin Islands (U.S.)
# 206            NaN             NaN     West Bank and Gaza
# 207            NaN             NaN            Yemen, Rep.
# 208         Zambia             NaN                 Zambia
# 209       Zimbabwe             NaN               Zimbabwe
#
#      Health_exp_pct_GDP_2016  Health_exp_public_pct_2016  \
# 200                      9.1                        71.7
# 201                      6.3                        46.1
# 202                      3.7                        53.9
# 203                      3.2                        24.1
# ...

# %% [markdown]
# # Cleaning dataset
#
#  Rename columns:

# %%
Health.corr
# Out:
# <bound method DataFrame.corr of     Country_Region  Province_State        World_Bank_Name  \
# 0      Afghanistan             NaN            Afghanistan
# 1          Albania             NaN                Albania
# 2          Algeria             NaN                Algeria
# 3          Andorra             NaN                Andorra
# 4           Angola             NaN                 Angola
# ..             ...             ...                    ...
# 205             US  Virgin Islands  Virgin Islands (U.S.)
# 206            NaN             NaN     West Bank and Gaza
# 207            NaN             NaN            Yemen, Rep.
# 208         Zambia             NaN                 Zambia
# 209       Zimbabwe             NaN               Zimbabwe
#
#      Health_exp_pct_GDP_2016  Health_exp_public_pct_2016  \
# 0                       10.2                         5.1
# 1                        6.7                        41.4
# 2                        6.6                        67.7
# ...

# %%
Health.columns
# Out:
# Index(['Country_Region', 'Province_State', 'World_Bank_Name',
#        'Health_exp_pct_GDP_2016', 'Health_exp_public_pct_2016',
#        'Health_exp_out_of_pocket_pct_2016', 'Health_exp_per_capita_USD_2016',
#        'per_capita_exp_PPP_2016', 'External_health_exp_pct_2016',
#        'Physicians_per_1000_2009-18', 'Nurse_midwife_per_1000_2009-18',
#        'Specialist_surgical_per_1000_2008-18',
#        'Completeness_of_birth_reg_2009-18',
#        'Completeness_of_death_reg_2008-16'],
#       dtype='object')

# %%
print(Health.columns)
# Out:
# Index(['Country_Region', 'Province_State', 'World_Bank_Name',
#        'Health_exp_pct_GDP_2016', 'Health_exp_public_pct_2016',
#        'Health_exp_out_of_pocket_pct_2016', 'Health_exp_per_capita_USD_2016',
#        'per_capita_exp_PPP_2016', 'External_health_exp_pct_2016',
#        'Physicians_per_1000_2009-18', 'Nurse_midwife_per_1000_2009-18',
#        'Specialist_surgical_per_1000_2008-18',
#        'Completeness_of_birth_reg_2009-18',
#        'Completeness_of_death_reg_2008-16'],
#       dtype='object')

# %%
Health.rename(columns={'Country_Region': 'country'}, inplace=True)
Health.rename(columns={'Province_State' : 'province'}, inplace = True)
Health.rename(columns={'World_Bank_Name': 'world_bank_name'}, inplace = True)
Health.rename(columns={'Health_exp_pct_GDP_2016' : 'expenditure_percentage_gdp'}, inplace = True)
Health.rename(columns={'Health_exp_public_pct_2016' : 'expenditure_percentage_public'}, inplace = True)
Health.rename(columns={'Health_exp_out_of_pocket_pct_2016' : 'expenditure_percentage_pocket'}, inplace = True)
Health.rename(columns={'Health_exp_per_capita_USD_2016' : 'per_capita_dollar'}, inplace = True)
Health.rename(columns={'per_capita_exp_PPP_2016' : 'per_capita_dollar_ppp'}, inplace = True)
Health.rename(columns={'External_health_exp_pct_2016' : 'external_money_percentage'}, inplace = True)
Health.rename(columns={'Physicians_per_1000_2009-18' : 'physicians_per_1000'}, inplace = True)
Health.rename(columns={'Nurse_midwife_per_1000_2009-18' : 'nurse_midwife_per_1000'}, inplace = True)
Health.rename(columns={'Specialist_surgical_per_1000_2008-18' : 'specialist_per_100000'}, inplace = True)
Health.rename(columns={'Completeness_of_birth_reg_2009-18' : 'birth_percentage'}, inplace = True)
Health.rename(columns={'Completeness_of_death_reg_2008-16' : 'death_percentage'}, inplace = True)

# %% [markdown]
# # correct type

# %%
Health.dtypes
# Out:
# country                           object
# province                          object
# world_bank_name                   object
# expenditure_percentage_gdp       float64
# expenditure_percentage_public    float64
# expenditure_percentage_pocket    float64
# per_capita_dollar                float64
# per_capita_dollar_ppp            float64
# external_money_percentage        float64
# physicians_per_1000              float64
# nurse_midwife_per_1000           float64
# specialist_per_100000            float64
# birth_percentage                 float64
# death_percentage                 float64
# dtype: object

# %%
Health['country'] = Health['country'].astype('string')
Health['province'] = Health['province'].astype('string')
Health['world_bank_name'] = Health['world_bank_name'].astype('string')

# %%
Health.dtypes
# Out:
# country                          string[python]
# province                         string[python]
# world_bank_name                  string[python]
# expenditure_percentage_gdp              float64
# expenditure_percentage_public           float64
# expenditure_percentage_pocket           float64
# per_capita_dollar                       float64
# per_capita_dollar_ppp                   float64
# external_money_percentage               float64
# physicians_per_1000                     float64
# nurse_midwife_per_1000                  float64
# specialist_per_100000                   float64
# birth_percentage                        float64
# death_percentage                        float64
# dtype: object

# %%
print(Health.dtypes)
# Out:
# country                          string[python]
# province                         string[python]
# world_bank_name                  string[python]
# expenditure_percentage_gdp              float64
# expenditure_percentage_public           float64
# expenditure_percentage_pocket           float64
# per_capita_dollar                       float64
# per_capita_dollar_ppp                   float64
# external_money_percentage               float64
# physicians_per_1000                     float64
# nurse_midwife_per_1000                  float64
# specialist_per_100000                   float64
# birth_percentage                        float64
# death_percentage                        float64
# dtype: object

# %%
Health.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   country                        187 non-null    string
#  1   province                       14 non-null     string
#  2   world_bank_name                210 non-null    string
#  3   expenditure_percentage_gdp     186 non-null    float64
#  4   expenditure_percentage_public  186 non-null    float64
#  5   expenditure_percentage_pocket  186 non-null    float64
#  6   per_capita_dollar              186 non-null    float64
#  7   per_capita_dollar_ppp          186 non-null    float64
#  8   external_money_percentage      167 non-null    float64
#  9   physicians_per_1000            189 non-null    float64
#  10  nurse_midwife_per_1000         189 non-null    float64
#  11  specialist_per_100000          175 non-null    float64
# ...

# %%
duplicates = Health.duplicated().sum() 
print(duplicates)
# Out:
# 0

# %% [markdown]
# # Replace missing values

# %%
Health.count()
# Out:
# country                          187
# province                          14
# world_bank_name                  210
# expenditure_percentage_gdp       186
# expenditure_percentage_public    186
# expenditure_percentage_pocket    186
# per_capita_dollar                186
# per_capita_dollar_ppp            186
# external_money_percentage        167
# physicians_per_1000              189
# nurse_midwife_per_1000           189
# specialist_per_100000            175
# birth_percentage                 163
# death_percentage                 107
# dtype: int64

# %%
Health.isnull()
# Out:
#      country  province  world_bank_name  expenditure_percentage_gdp  \
# 0      False      True            False                       False
# 1      False      True            False                       False
# 2      False      True            False                       False
# 3      False      True            False                       False
# 4      False      True            False                       False
# ..       ...       ...              ...                         ...
# 205    False     False            False                        True
# 206     True      True            False                        True
# 207     True      True            False                       False
# 208    False      True            False                       False
# 209    False      True            False                       False
#
#      expenditure_percentage_public  expenditure_percentage_pocket  \
# 0                            False                          False
# ...

# %% [markdown]
# # Descriptive analysis

# %%
Health.describe()
# Out:
#        expenditure_percentage_gdp  expenditure_percentage_public  \
# count                  186.000000                     186.000000
# mean                     6.715054                      52.915054
# std                      2.976537                      21.957736
# min                      1.700000                       5.100000
# 25%                      4.500000                      36.825000
# 50%                      6.200000                      55.850000
# 75%                      8.375000                      70.600000
# max                     23.300000                      96.000000
#
#        expenditure_percentage_pocket  per_capita_dollar  \
# count                     186.000000         186.000000
# mean                       32.661828        1037.004839
# std                        19.572777        1712.592621
# min                         0.100000          16.400000
# 25%                        16.200000          85.700000
# ...

# %%
Health.max()
# Out:
# country                                Zimbabwe
# province                         Virgin Islands
# world_bank_name                        Zimbabwe
# expenditure_percentage_gdp                 23.3
# expenditure_percentage_public              96.0
# expenditure_percentage_pocket              81.0
# per_capita_dollar                        9869.7
# per_capita_dollar_ppp                    9869.7
# external_money_percentage                  69.2
# physicians_per_1000                         8.2
# nurse_midwife_per_1000                     20.3
# specialist_per_100000                     195.6
# birth_percentage                          100.0
# death_percentage                          100.0
# dtype: object

# %%
Health.min()
# Out:
# country                             Afghanistan
# province                         Cayman Islands
# world_bank_name                     Afghanistan
# expenditure_percentage_gdp                  1.7
# expenditure_percentage_public               5.1
# expenditure_percentage_pocket               0.1
# per_capita_dollar                          16.4
# per_capita_dollar_ppp                      29.9
# external_money_percentage                   0.0
# physicians_per_1000                         0.0
# nurse_midwife_per_1000                      0.1
# specialist_per_100000                       0.0
# birth_percentage                            2.7
# death_percentage                            4.0
# dtype: object

# %%
Health.isnull().sum()
# Out:
# country                           23
# province                         196
# world_bank_name                    0
# expenditure_percentage_gdp        24
# expenditure_percentage_public     24
# expenditure_percentage_pocket     24
# per_capita_dollar                 24
# per_capita_dollar_ppp             24
# external_money_percentage         43
# physicians_per_1000               21
# nurse_midwife_per_1000            21
# specialist_per_100000             35
# birth_percentage                  47
# death_percentage                 103
# dtype: int64

# %%
Health.std
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.std of          country        province        world_bank_name  \
# 0    Afghanistan            <NA>            Afghanistan
# 1        Albania            <NA>                Albania
# 2        Algeria            <NA>                Algeria
# 3        Andorra            <NA>                Andorra
# 4         Angola            <NA>                 Angola
# ..           ...             ...                    ...
# 205           US  Virgin Islands  Virgin Islands (U.S.)
# 206         <NA>            <NA>     West Bank and Gaza
# 207         <NA>            <NA>            Yemen, Rep.
# 208       Zambia            <NA>                 Zambia
# 209     Zimbabwe            <NA>               Zimbabwe
#
#      expenditure_percentage_gdp  expenditure_percentage_public  \
# 0                          10.2                            5.1
# 1                           6.7                           41.4
# ...

# %%
Health.sample()
# Out:
#    country          province   world_bank_name  expenditure_percentage_gdp  \
# 66  France  French Polynesia  French Polynesia                         NaN
#
#     expenditure_percentage_public  expenditure_percentage_pocket  \
# 66                            NaN                            NaN
#
#     per_capita_dollar  per_capita_dollar_ppp  external_money_percentage  \
# 66                NaN                    NaN                        NaN
#
#     physicians_per_1000  nurse_midwife_per_1000  specialist_per_100000  \
# 66                  NaN                     NaN                   32.6
#
#     birth_percentage  death_percentage
# 66               NaN               NaN

# %% [markdown]
# # Exploring Health Systems

# %%
print(Health.country.count())
# Out:
# 187

# %%
print(Health.country.tolist())
# Out:
# ['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bhutan', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil', 'Brunei', 'Bulgaria', 'Burkina Faso', 'Burundi', 'Cabo Verde', 'Cambodia', 'Cameroon', 'Canada', 'United Kingdom', 'Central African Republic', 'Chad', 'United Kingdom', 'Chile', 'China', 'China', 'China', 'Colombia', 'Comoros', 'Congo (Kinshasa)', 'Congo (Brazzaville)', 'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Cyprus', 'Czechia', 'Denmark', 'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia', 'Eswatini', 'Ethiopia', 'Denmark', 'Fiji', 'Finland', 'France', 'France', 'Gabon', 'Gambia', 'Georgia', 'Germany', 'Ghana', 'Greece', 'Denmark', 'Grenada', 'US', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Guyana', 'Haiti'
# ...

# %%
Health.shape
# Out:
# (210, 14)

# %% [markdown]
# # Box ploting

# %%
plt.figure(figsize=(40, 20))
sns.boxplot(x='expenditure_percentage_gdp', y='external_money_percentage', data=Health, palette='YlGnBu')  # Fix the color palette name

plt.show()

# %% [markdown]
# # Heatmap

# %%
# Exclude non-numeric columns from the correlation matrix
numeric_health = Health.select_dtypes(include=[np.number])

# Compute the correlation matrix
corr_matrix = numeric_health.corr()

# Set up the matplotlib figure
plt.figure(figsize=(12, 10))

# Create a heatmap with seaborn
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", fmt=".2f", vmin=-1, vmax=1)  

# Show the plot
plt.title('World Bank dataset')
plt.show()

# %% [markdown]
# # Data visualization

# %%
plt.figure(figsize=(12, 8))
sns.histplot(Health["nurse_midwife_per_1000"], bins=30, color="red", kde=True)  # You can use histplot
plt.title("Nurse Midwife per 1000")
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.histplot(Health["physicians_per_1000"], bins=30, color="red", kde=True)  # You can use histplot
plt.title("physicians_per_1000")
plt.show()

# %% [markdown]
# # Scatter plot

# %%
 plt.figure(figsize=(15,6))
plt.scatter(Health["physicians_per_1000"],Health["nurse_midwife_per_1000"])
plt.xlabel('physicians_per_1000')
plt.ylabel('nurse_midwife_per_1000')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 6))  # Use a tuple for figsize
plt.scatter(Health["death_percentage"], Health["birth_percentage"])
plt.xlabel('death_percentage')
plt.ylabel('birth_percentage')
plt.show()
